# %% [markdown]
# <a href="https://colab.research.google.com/github/WellingtonRoque/TPII/blob/main/aula05_tecnicas_programacao_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Técnicas de Programação II
# ## Aula 5 — Layout com Bootstrap
#
# Projeto do semestre:
#
# ## 🛒 Sistema de Catálogo de Produtos
#
# Até a aula anterior conseguimos:
#
# - criar uma aplicação Flask
# - organizar o projeto em MVC
# - criar páginas HTML com templates
#
# Agora vamos melhorar **a aparência do sistema**, criando um **layout profissional** usando **Bootstrap**.

# %% [markdown]
# # 🎯 Objetivos da Aula
#
# Ao final desta aula você será capaz de:
#
# - entender o que é **Bootstrap**
# - criar um **layout base reutilizável**
# - criar **menu de navegação**
# - reutilizar páginas com **base.html**
# - melhorar o visual do sistema

# %% [markdown]
# # 🔁 Revisão da Aula Anterior
#
# Na aula anterior aprendemos:
#
# - o que são templates
# - como usar HTML no Flask
# - como usar **Jinja2**
# - como mostrar dados dinamicamente
#
# Exemplo de template:

# %%
<h1>Lista de Produtos</h1>

<ul>
{% for produto in produtos %}
    <li>{{ produto }}</li>
{% endfor %}
</ul>

# %% [markdown]
# Embora funcione, a página ainda é **visualment​e simples**.
#
# Aplicações reais utilizam **frameworks de interface**.

# %% [markdown]
# # 🎨 O que é Bootstrap?
#
# Bootstrap é um **framework CSS** que facilita a criação de interfaces modernas.
#
# Ele oferece:
#
# - layout responsivo
# - componentes prontos
# - botões
# - menus
# - formulários
# - tabelas

# %% [markdown]
# Site oficial:
#
# https://getbootstrap.com

# %% [markdown]
# # 🚀 Usando Bootstrap
#
# Podemos utilizar Bootstrap adicionando este link dentro do HTML:

# %%
<link
href="https://cdn.jsdelivr.net/npm/bootstrap@5.3.2/dist/css/bootstrap.min.css"
rel="stylesheet">

# %% [markdown]
# # 📄 Criando um Layout Base
#
# Em aplicações web normalmente criamos um **layout base** que será reutilizado.
#
# Crie o arquivo:
#
# ```
# templates/base.html
# ```

# %%
<!DOCTYPE html>
<html>
<head>

<title>Sistema de Produtos</title>

<link href="https://cdn.jsdelivr.net/npm/bootstrap@5.3.2/dist/css/bootstrap.min.css" rel="stylesheet">

</head>

<body>

<nav class="navbar navbar-dark bg-dark">
    <div class="container">
        <a class="navbar-brand" href="/">Sistema de Produtos</a>
    </div>
</nav>

<div class="container mt-4">

{% block conteudo %}

{% endblock %}

</div>

</body>
</html>

# %% [markdown]
# Observe que criamos um bloco chamado:
#
# ```
# {% block conteudo %}
# ```

# %% [markdown]
# # 📄 Criando a Página de Produtos
#
# Agora vamos criar:
#
# ```
# templates/produtos.html
# ```

# %%
{% extends "base.html" %}

{% block conteudo %}

<h1>Lista de Produtos</h1>

<ul class="list-group">

{% for produto in produtos %}
<li class="list-group-item">{{ produto }}</li>
{% endfor %}

</ul>

{% endblock %}

# %% [markdown]
# Observe que utilizamos:
#
# ```
# {% extends "base.html" %}
# ```

# %% [markdown]
# Isso significa que **a página utiliza o layout base**.

# %% [markdown]
# # 🧠 Atualizando o Controller

# %%
from flask import render_template

def produto_routes(app):

    produtos = [
        "Notebook",
        "Mouse",
        "Teclado"
    ]

    @app.route("/produtos")
    def listar_produtos():
        return render_template("produtos.html", produtos=produtos)

# %% [markdown]
# Agora o sistema possui:
#
# - layout profissional
# - menu superior
# - lista estilizada

# %% [markdown]
# # 🧪 Exercício Guiado
#
# Adicione novos produtos:
#
# - Monitor
# - Webcam
# - Headset
#
# Veja como a lista aparece estilizada.

# %% [markdown]
# # 🧪 Exercícios
#
# ## Exercício 1
#
# Crie uma página:
#
# ```
# templates/home.html
# ```
#
# Mostre:
#
# ```
# Bem-vindo ao Sistema de Produtos
# ```

# %% [markdown]
# ## Exercício 2
#
# Crie uma página:
#
# ```
# templates/categorias.html
# ```
#
# Mostre:
#
# - Informática
# - Periféricos
# - Acessórios

# %% [markdown]
# # 🚀 Desafio
#
# Melhore a navegação do sistema.
#
# Adicione links no menu:
#
# - Home
# - Produtos
# - Categorias

# %% [markdown]
# # 📌 Conclusão
#
# Nesta aula aprendemos:
#
# - o que é Bootstrap
# - como criar layout reutilizável
# - como usar **base.html**
# - como melhorar a interface do sistema

# %% [markdown]
# # 🔜 Próxima Aula
#
# Na próxima aula iremos aprender:
#
# ## 🗄 Banco de Dados com SQLAlchemy
#
# Nosso sistema passará a:
#
# - salvar produtos no banco
# - listar produtos do banco
# - preparar o sistema para CRUD
